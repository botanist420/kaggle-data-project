# %%
import pandas as pd 
import numpy as np

# %%
# Spotify artist data
url = 'https://storage.googleapis.com/kagglesdsdata/datasets/2495939/4234994/spotify_artist_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221007%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221007T114944Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
df = pd.read_csv(url).drop('Unnamed: 0', axis=1)
df.head()
# Out:
#     Artist Name    Lead Streams           Feats Tracks One Billion  \
# 0         Drake  50,162,292,808  19,246,513,666    262           6
# 1     Bad Bunny  44,369,032,140   5,391,990,975    163           5
# 2    Ed Sheeran  38,153,682,361   2,791,278,201    240          10
# 3    The Weeknd  34,767,779,741   4,288,903,657    186           8
# 4  Taylor Swift  32,596,728,109     424,053,296    323           1
#
#   100 Million Last Updated
# 0         130     19.09.22
# 1         118     20.09.22
# 2          62     19.09.22
# 3          72     19.09.22
# 4          96     20.09.22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Artist Name   1009 non-null   object
#  1   Lead Streams  1009 non-null   object
#  2   Feats         1009 non-null   object
#  3   Tracks        1009 non-null   object
#  4   One Billion   1009 non-null   object
#  5   100 Million   1009 non-null   object
#  6   Last Updated  1009 non-null   object
# dtypes: object(7)
# memory usage: 55.3+ KB

# %%
# spotify 2000-2019
url_spotify = "https://storage.googleapis.com/kagglesdsdata/datasets/2125460/3723559/songs_normalize.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221007%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221007T125910Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

df_song = pd.read_csv(url_spotify)

# %%
df_song.head()

df_song.duration_ms.describe()
# 1 sec = 1000 ms

# to minutes
(df_song.duration_ms/1000/60).hist(bins=np.arange(1.8, 8.1, 0.652276))
# Out:
# <AxesSubplot:>

# %%
# df_song

condition = df_song.year == 2019

condition_genre_hip_hop = df_song.genre.str.contains('hip hop')

df_song[condition_genre_hip_hop].sort_values(by='popularity', ascending=False)
# Out:
#                       artist                          song  duration_ms  \
# 201                   Eminem                    Without Me       290320
# 6                     Eminem           The Real Slim Shady       284200
# 1999             Post Malone                       Circles       215280
# 209                   Eminem              'Till I Collapse       297786
# 1701               Sean Paul                        No Lie       221176
# ...                      ...                           ...          ...
# 1750          Kendrick Lamar                          DNA.       185946
# 1751  A Boogie Wit da Hoodie  Drowning (feat. Kodak Black)       209269
# 778                Jim Jones                   We Fly High       236080
# 1781                   Drake                  Passionfruit       298940
# 1677              Tory Lanez                           LUV       228640
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
# Find the artist Drake
condition_artist = df_song['artist'] == 'Drake'
df_song[condition_artist].sort_values('popularity', ascending=False)
# Out:
#      artist                                      song  duration_ms  explicit  \
# 1601  Drake                                 One Dance       173986     False
# 1800  Drake                                God's Plan       198973      True
# 1558  Drake                             Hotline Bling       267066     False
# 1897  Drake                             Nice For What       210746      True
# 1822  Drake                                   Nonstop       238614      True
# 1938  Drake  Money In The Grave (Drake ft. Rick Ross)       205426      True
# 1296  Drake                                 Take Care       277386      True
# 1869  Drake                            In My Feelings       217925      True
# 1699  Drake                                  Too Good       263373      True
# 1289  Drake                                 The Motto       181573      True
# 1172  Drake                                 Headlines       235986      True
# ...
